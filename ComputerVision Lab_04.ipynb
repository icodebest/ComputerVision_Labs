# %% [markdown]
# # **Computer Vision Lab_04**
# -----
# ## Advanced Morphological Operations
# Objective: Understand and implement advanced morphological operations:
# - Opening and Closing
# - Morphological Gradient
# - Top-Hat Transformation
# - Black-Hat Transformation

# %% [markdown]
# ## Step 1: Import Required Libraries

# %%
import cv2
import numpy as npz
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Load Image and Convert to Grayscale

# %%
# Load image
image_path = "/content/RadialGradient.png" # Replace with your image path
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
# Display the image
plt.imshow(image, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')
plt.show()

# %%
# Load image
image_path1 = "/content/tint1.jpg" # Replace with your image path
image1 = cv2.imread(image_path1, cv2.IMREAD_GRAYSCALE)

# %%
# Display the image
plt.imshow(image1, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 3: Apply Morphological Operations
# Morphological operations are techniques that process images based on their shapes. They are used for tasks such as noise removal, image enhancement, and feature extraction. The two fundamental
# operations covered in this lab are:
# 1. **Opening (Erosion followed by Dilation)** - Removes small white noise (salt noise).
# 2. **Closing (Dilation followed by Erosion)** - Removes small black noise (pepper noise).
# Both operations use a structuring element (kernel) to define the transformation's shape and size.

# %%
# Define a Structuring element(kernal)
kernel=np.ones((5,5),np.uint8) # 5*5 square kernal

# %%
# Applying opening (Erosion Followed by Dilation)
opening=cv2.morphologyEx(image1,cv2.MORPH_OPEN,kernel)

# %%
# Apply Closing (Dilation followed by Erosion)
closing = cv2.morphologyEx(image1, cv2.MORPH_CLOSE, kernel)

# %%
# Display images
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].imshow(image1, cmap='gray')
ax[0].set_title("Original Image")
ax[0].axis('off')

ax[1].imshow(opening, cmap='gray')
ax[1].set_title("After Opening (Erosion → Dilation)")
ax[1].axis('off')

ax[2].imshow(closing, cmap='gray')
ax[2].set_title("After Closing (Dilation → Erosion)")
ax[2].axis('off')

plt.show()

# %% [markdown]
# ## Step 4: Apply Morphological Gradient

# %%
# Define a 5x5 kernel
kernel = np.ones((5,5), np.uint8)

# Apply morphological gradient
gradient = cv2.morphologyEx(image, cv2.MORPH_GRADIENT, kernel)

# Display images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(gradient, cmap='gray'), plt.title("Morphological Gradient")
plt.show()

# %% [markdown]
# ### Explanation:
# - Kernel (5x5): Defines the neighborhood for morphological operations.
# - Morphological Gradient = Dilation - Erosion → Highlights object edges.
# - Use Case: Helps detect object boundaries.

# %% [markdown]
# ## Step 5: Apply Top-Hat Transformation

# %%
# Apply top-hat transformation
top_hat = cv2.morphologyEx(image, cv2.MORPH_TOPHAT, kernel)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(top_hat, cmap='gray'), plt.title("Top-Hat Transformation")
plt.show()

# %% [markdown]
# ### Explanation:
# - Top-Hat Transformation: Extracts small bright details from the image.
# - How it works?
# 1. First, the image undergoes opening (erosion → dilation).
# 2. The result is subtracted from the original image, leaving bright details.

# %% [markdown]
# ## Step 6: Apply Black-Hat Transformation

# %%
# Apply black-hat transformation
black_hat = cv2.morphologyEx(image, cv2.MORPH_BLACKHAT, kernel)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(black_hat, cmap='gray'), plt.title("Black-Hat Transformation")
plt.show()

# %% [markdown]
# ### Explanation:
# - Black-Hat Transformation: Extracts dark features from the image.
#
# `**How it works?**`
# -First, the image undergoes closing (dilation → erosion).
# -The result is subtracted from the original image, leaving dark features.

# %% [markdown]
# ## Task for Students:
# - Try different kernel sizes and observe the effect.
# - Test on an image with shadows or handwritten text.

# %%
# Load image
image_path_text = "/content/text.jpg" # Replace with your image path
text_image = cv2.imread(image_path_text, cv2.IMREAD_GRAYSCALE)

# %%
# Display the image
plt.imshow(text_image, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')
plt.show()

# %%
# Define a Structuring element(kernal)
kernel_2=np.ones((3,3),np.uint8) # 5*5 square kernal

# %%
# Apply morphological gradient on text image
gradient = cv2.morphologyEx(text_image, cv2.MORPH_GRADIENT, kernel_2)

# Display images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(text_image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(gradient, cmap='gray'), plt.title("Morphological Gradient")
plt.show()

# %%
kernel_3=np.ones((8,8),np.uint8) # Kernal with 8*8

# %%
# Apply top-hat transformation on text images
top_hat = cv2.morphologyEx(text_image, cv2.MORPH_TOPHAT, kernel_2)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(text_image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(top_hat, cmap='gray'), plt.title("Top-Hat Transformation")
plt.show()

# %%
# Apply top-hat transformation on text images with kernal_3
top_hat = cv2.morphologyEx(text_image, cv2.MORPH_TOPHAT, kernel_3)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(text_image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(top_hat, cmap='gray'), plt.title("Top-Hat Transformation")
plt.show()

# %%
# Apply black-hat transformation On text image with 3*3 kernal
black_hat = cv2.morphologyEx(text_image, cv2.MORPH_BLACKHAT, kernel_2)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(text_image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(black_hat, cmap='gray'), plt.title("Black-Hat Transformation")
plt.show()

# %%
# Apply black-hat transformation On text image 8*8 kernal
black_hat = cv2.morphologyEx(text_image, cv2.MORPH_BLACKHAT, kernel_3)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(text_image, cmap='gray'), plt.title("Original Image")
plt.subplot(1,2,2), plt.imshow(black_hat, cmap='gray'), plt.title("Black-Hat Transformation")
plt.show()
