# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

# Retrieve stored GitHub token securely
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

if GITHUB_TOKEN:
    print("✅ GitHub token loaded securely!")
else:
    print("❌ ERROR: GitHub token not found!")
# Out:
# ✅ GitHub token loaded securely!

# %%
# Set your Git credentials
# !git config --global user.email "waleedusmanf22@nutech.edu.pk"
# !git config --global user.name "icodebest"

# %%
##!git clone https://icodebest:{GITHUB_TOKEN}@github.com/icodebest/ComputerVision_Labs.git

# %%
# %cd /content/drive/MyDrive/Computer Vision Labs/ComputerVision_Labs
# Out:
# /content/drive/MyDrive/Computer Vision Labs/ComputerVision_Labs

# %%
# Update the remote URL to use the token for authentication
# !git remote set-url origin https://icodebest:{GITHUB_TOKEN}@github.com/icodebest/ComputerVision_Labs.git

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "Computer Vision Mid Semester Exam"
# Out:
# [main f551d76] Computer Vision Mid Semester Exam
#  4 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Computer Vision Lab_08.ipynb
#  create mode 100644 Computer_Vision_Lab_08.pdf
#  create mode 100644 Lab 8.pptx

# %%
# !git push origin main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 6.77 MiB | 4.62 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/icodebest/ComputerVision_Labs.git
#    ede1ffa..bc02390  main -> main
